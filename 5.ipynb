# %% [markdown]
# # Шаталин Александр
# ## Рабочая тетрадь 5

# %% [markdown]
# ### 1.1 Задание

# %%
import numpy as np
import math

class Trigonometry:
    def __init__(self) -> None:
        pass

    def calculate(self, command: str) -> float:
        split_cmd = command.strip().split(' ')
        return self.__inner_calculate__(split_cmd)
        

    def __inner_calculate__(self, split_cmd) -> float:
        reduced_str = ' '.join(split_cmd[1:]).strip().split()
        
        if split_cmd[0] == 'cos':
            print('cos')
            return np.cos(self.__inner_calculate__(reduced_str))
        elif split_cmd[0] == 'sin':
            print('sin')
            result = np.sin(self.__inner_calculate__(reduced_str))
            return result
        elif split_cmd[0] == 'tg':
            print('tg')
            return np.tan(self.__inner_calculate__(reduced_str))
        elif split_cmd[0] == 'arccos':
            print('arccos')
            return np.arccos(self.__inner_calculate__(reduced_str))
        elif split_cmd[0] == 'arcsin':
            print('arcsin')
            return np.arcsin(self.__inner_calculate__(reduced_str))
        elif split_cmd[0] == 'arctg':
            print('arctg')
            return np.arctan(self.__inner_calculate__(reduced_str))
        elif split_cmd[0] == 'rad':
            print('rad')
            return math.radians(self.__inner_calculate__(reduced_str))
        elif split_cmd[0] == 'deg':
            print('deg')
            return math.degrees(self.__inner_calculate__(reduced_str))
        else:
            return float(split_cmd[0])

# %%
t = Trigonometry()
t.calculate('   deg sin  cos  tg   arctg arccos    rad   deg    arcsin rad    45')
# Out:
# deg
# sin
# cos
# tg
# arctg
# arccos
# rad
# deg
# arcsin
# rad
# 45.0

# %% [markdown]
# ### 1.2.1 Задание

# %%
tree = {'a': [{'b': [{'d': []}, {'e': []}]}, {'c': {'f': []}}]}
print(tree['a'])
print(tree['a'][0]['b'])
print(tree['a'][1]['c'])
# Out:
# [{'b': [{'d': []}, {'e': []}]}, {'c': {'f': []}}]
# [{'d': []}, {'e': []}]
# {'f': []}

# %% [markdown]
# ### 1.2.2 Задание

# %%
class Tree:
    def __init__(self, data):
        self.left = None 
        self.right = None 
        self.data = data
        
    def PrintTree(self): 
        print(self.data)

    def print_tree(self):
        
        print(f'height: {self.height()} data: {self.data}')
        if self.left is not None:
            self.left.print_tree()
        if self.right is not None:
           self.right.print_tree()
        
        #print(self.collect_data())

    def collect_data(self):
        layers_data = []

        if self.left is not None:
            layers_data.append(self.left.collect_data())
        if self.right is not None:
           layers_data.append(self.right.collect_data())

        layers_data.append({self.height(): self.data})

        return layers_data

    def height(self):
        if self.left is None:
            l_height = 0
        else:
            l_height = self.left.height() 

        if self.right is None:
            r_height = 0
        else:
            r_height = self.right.height()
        return max(l_height, r_height) + 1

    def append_element(self, tree):
        if tree.data < self.data:
            if self.left is None:
                self.left = tree
            else:
                self.left.append_element(tree)
        elif tree.data > self.data:
            if self.right is None:
                self.right = tree
            else:
                self.right.append_element(tree)
        else:
            pass

# %%
tree = Tree(23)

for i in range(3, 39, 3):
    tree.append_element(Tree(i))

for i in range(1, 39, 3):
    tree.append_element(Tree(i))
    
tree.print_tree()
# Out:
# height: 9 data: 23
# height: 8 data: 3
# height: 1 data: 1
# height: 7 data: 6
# height: 1 data: 4
# height: 6 data: 9
# height: 1 data: 7
# height: 5 data: 12
# height: 1 data: 10
# height: 4 data: 15
# height: 1 data: 13
# height: 3 data: 18
# height: 1 data: 16
# height: 2 data: 21
# height: 1 data: 19
# height: 1 data: 22
# height: 6 data: 24
# height: 5 data: 27
# height: 1 data: 25
# height: 4 data: 30
# height: 1 data: 28
# height: 3 data: 33
# height: 1 data: 31
# height: 2 data: 36
# height: 1 data: 34
# height: 1 data: 37

# %% [markdown]
# ### 1.3 Задание

# %%
from sklearn.model_selection import train_test_split

X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 2], [3, 2]])
target = [0, 0, 0, 1, 1, 1]

X_train, X_test, y_train, y_test = train_test_split(
    X, 
    target, 
    test_size=0.2
    )

X_train, y_train
# Out:
# (array([[ 2,  2],
#         [-1, -1],
#         [ 1,  1],
#         [ 3,  2]]),
#  [1, 0, 1, 1])

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)

tree.plot_tree(classifier)
# Out:
# [Text(0.5, 0.75, 'X[0] <= 0.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %%
y_pred = classifier.predict(X_test)
y_pred, y_test
# Out:
# (array([0, 0]), [0, 0])

# %% [markdown]
# ### 1.4 Задание

# %%
import pandas as pd
df = pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(df['quality'], df['fixed acidity'], s=5, color='b', label='wine quality')
plt.scatter(df['quality'], df['volatile acidity'], s=30, color='r', label='wine quality')
plt.scatter(df['quality'], df['citric acid'], s=10, color='c', label='wine quality')
plt.scatter(df['quality'], df['pH'], s=5, color='y', label='wine quality')
plt.xlabel('quality')
plt.ylabel('acidity')
plt.show()

plt.scatter(df['quality'], df['free sulfur dioxide'], s=25, color='k', label='wine quality')
plt.scatter(df['quality'], df['total sulfur dioxide'], s=5, color='y', label='wine quality')
plt.xlabel('quality')
plt.ylabel('dioxide')
plt.show()

plt.scatter(df['quality'], df['residual sugar'], s=50, color='g', label='wine quality')
plt.scatter(df['quality'], df['chlorides'], s=30, color='m', label='wine quality')
plt.scatter(df['quality'], df['density'], s=10, color='c', label='wine quality')
plt.scatter(df['quality'], df['sulphates'], s=5, color='y', label='wine quality')
plt.xlabel('quality')
plt.ylabel('other metrics')
plt.show()

plt.scatter(df['quality'], df['alcohol'], color='k', label='wine quality')
plt.xlabel('quality')
plt.ylabel('alcohol')
plt.show()

# %%
X = pd.DataFrame(df.iloc[:, :-1])
y = pd.DataFrame(df.iloc[:, -1])
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
y.head()
# Out:
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=0.2
    )

X_train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1114            5.0              0.40         0.50             4.3      0.046
# 1283            8.7              0.63         0.28             2.7      0.096
# 260             7.9              0.33         0.23             1.7      0.077
# 853             9.3              0.36         0.39             1.5      0.080
# 52              6.6              0.50         0.04             2.1      0.068
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1114                 29.0                  80.0  0.99020  3.49       0.66
# 1283                 17.0                  69.0  0.99734  3.26       0.63
# 260                  18.0                  45.0  0.99625  3.29       0.65
# 853                  41.0                  55.0  0.99652  3.47       0.73
# 52                    6.0                  14.0  0.99550  3.39       0.64
#
#       alcohol
# 1114     13.6
# 1283     10.2
# ...

# %%
from sklearn.tree import DecisionTreeRegressor

regressor = DecisionTreeRegressor()
regressor.fit(X_train, y_train)

tree.plot_tree(classifier)
# Out:
# [Text(0.5787698158583788, 0.9761904761904762, 'X[10] <= 10.25\ngini = 0.641\nsamples = 1279\nvalue = [9, 44, 548, 512, 151, 15]'),
#  Text(0.3487466558515483, 0.9285714285714286, 'X[6] <= 98.5\ngini = 0.519\nsamples = 663\nvalue = [6, 23, 410, 206, 16, 2]'),
#  Text(0.22390496926229508, 0.8809523809523809, 'X[9] <= 0.575\ngini = 0.548\nsamples = 587\nvalue = [6, 23, 338, 202, 16, 2]'),
#  Text(0.0977629781420765, 0.8333333333333334, 'X[4] <= 0.094\ngini = 0.463\nsamples = 232\nvalue = [4, 15, 162, 49, 2, 0]'),
#  Text(0.047984972677595626, 0.7857142857142857, 'X[10] <= 9.075\ngini = 0.498\nsamples = 201\nvalue = [3, 14, 133, 49, 2, 0]'),
#  Text(0.014571948998178506, 0.7380952380952381, 'X[8] <= 3.345\ngini = 0.7\nsamples = 10\nvalue = [1, 3, 2, 4, 0, 0]'),
#  Text(0.007285974499089253, 0.6904761904761905, 'X[2] <= 0.55\ngini = 0.5\nsamples = 6\nvalue = [1, 0, 1, 4, 0, 0]'),
#  Text(0.0036429872495446266, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
# ...

# %%
y_pred = regressor.predict(X_test)
y_pred[:5], y_test[:5]
# Out:
# (array([5., 6., 6., 5., 5.]),
#        quality
#  834         5
#  405         6
#  1474        5
#  988         5
#  1232        5)

# %%
from sklearn import metrics
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MPE:', metrics.mean_absolute_error(y_test, y_pred) / np.average(y) * 100)
# Out:
# MSE: 0.73125
# MAE: 0.5125
# MPE: 9.093292276964048
